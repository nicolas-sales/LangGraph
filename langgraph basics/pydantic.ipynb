# %%
from langgraph.graph import StateGraph,START,END
from pydantic import BaseModel

# %%
class State(BaseModel):
    name:str

# %%
# node function

def example_node(state:State):
    return {"name":"Hello"}

# %%
builder=StateGraph(State)

builder.add_node("example_node",example_node)

builder.add_edge(START,"example_node")

builder.add_edge("example_node",END)

graph = builder.compile()

# %%
graph.invoke({"name":"Nico"})
# Out:
# {'name': 'Hello'}

# %%
graph.invoke({"name":123})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 graph.invoke({"name":123})
#
# File c:\Users\nico_\Desktop\Agentic\AgenticAI\venvagentic\Lib\site-packages\langgraph\pregel\main.py:3365, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3362             chunks.append(chunk)
#    3363 else:
#    3364     # v1: collect interrupts from updates stream
# -> 3365     for chunk in self.stream(
#    3366         input,
#    3367         config,
#    3368         context=context,
#    3369         stream_mode=(
#    3370             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3371         ),
#    3372         print_mode=print_mode,
#    3373         output_keys=output_keys,
#    3374         interrupt_before=interrupt_before,
#    3375         interrupt_after=interrupt_after,
#    3376         durability=durability,
#    3377         **kwargs,
#    3378     ):
#    3379         if stream_mode == "values":
#    3380             if len(chunk) == 2:
#
# File c:\Users\nico_\Desktop\Agentic\AgenticAI\venvagentic\Lib\site-packages\langgraph\pregel\main.py:2756, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#    2749             return waiter
#    2751 # Similarly to Bulk Synchronous Parallel / Pregel model
#    2752 # computation proceeds in steps, while there are channel updates.
#    2753 # Channel updates from step N are only visible in step N+1
#    2754 # channels are guaranteed to be immutable for the duration of the step,
#    2755 # with channel updates applied only at the transition between steps.
# -> 2756 while loop.tick():
#    2757     for task in loop.match_cached_writes():
#    2758         loop.output_writes(task.id, task.writes, cached=True)
#
# File c:\Users\nico_\Desktop\Agentic\AgenticAI\venvagentic\Lib\site-packages\langgraph\pregel\_loop.py:519, in PregelLoop.tick(self)
#     516     return False
#     518 # prepare next tasks
# --> 519 self.tasks = prepare_next_tasks(
#     520     self.checkpoint,
#     521     self.checkpoint_pending_writes,
#     522     self.nodes,
#     523     self.channels,
#     524     self.managed,
#     525     self.config,
#     526     self.step,
#     527     self.stop,
#     528     for_execution=True,
#     529     manager=self.manager,
#     530     store=self.store,
#     531     checkpointer=self.checkpointer,
#     532     trigger_to_nodes=self.trigger_to_nodes,
#     533     updated_channels=self.updated_channels,
#     534     retry_policy=self.retry_policy,
#     535     cache_policy=self.cache_policy,
#     536 )
#     538 # produce debug output
#     539 if self._checkpointer_put_after_previous is not None:
#
# File c:\Users\nico_\Desktop\Agentic\AgenticAI\venvagentic\Lib\site-packages\langgraph\pregel\_algo.py:469, in prepare_next_tasks(checkpoint, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, trigger_to_nodes, updated_channels, retry_policy, cache_policy)
#     466 # Check if any processes should be run in next step
#     467 # If so, prepare the values to be passed to them
#     468 for name in candidate_nodes:
# --> 469     if task := prepare_single_task(
#     470         (PULL, name),
#     471         None,
#     472         checkpoint=checkpoint,
#     473         checkpoint_id_bytes=checkpoint_id_bytes,
#     474         checkpoint_null_version=null_version,
#     475         pending_writes=pending_writes,
#     476         processes=processes,
#     477         channels=channels,
#     478         managed=managed,
#     479         config=config,
#     480         step=step,
#     481         stop=stop,
#     482         for_execution=for_execution,
#     483         store=store,
#     484         checkpointer=checkpointer,
#     485         manager=manager,
#     486         input_cache=input_cache,
#     487         cache_policy=cache_policy,
#     488         retry_policy=retry_policy,
#     489     ):
#     490         tasks.append(task)
#     491 return {t.id: t for t in tasks}
#
# File c:\Users\nico_\Desktop\Agentic\AgenticAI\venvagentic\Lib\site-packages\langgraph\pregel\_algo.py:615, in prepare_single_task(task_path, task_id_checksum, checkpoint, checkpoint_id_bytes, checkpoint_null_version, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, input_cache, cache_policy, retry_policy)
#     613 # create task input
#     614 try:
# --> 615     val = _proc_input(
#     616         proc,
#     617         managed,
#     618         channels,
#     619         for_execution=for_execution,
#     620         input_cache=input_cache,
#     621         scratchpad=scratchpad,
#     622     )
#     623     if val is MISSING:
#     624         return
#
# File c:\Users\nico_\Desktop\Agentic\AgenticAI\venvagentic\Lib\site-packages\langgraph\pregel\_algo.py:1184, in _proc_input(proc, managed, channels, for_execution, scratchpad, input_cache)
#    1182 # If the process has a mapper, apply it to the value
#    1183 if for_execution and proc.mapper is not None:
# -> 1184     val = proc.mapper(val)
#    1186 # Cache the input value
#    1187 if input_cache is not None:
#
# File c:\Users\nico_\Desktop\Agentic\AgenticAI\venvagentic\Lib\site-packages\langgraph\graph\state.py:1534, in _coerce_state(schema, input)
#    1533 def _coerce_state(schema: type[_S], input: dict[str, Any]) -> _S:
# -> 1534     return schema(**input)
#
# File c:\Users\nico_\Desktop\Agentic\AgenticAI\venvagentic\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for State
# name
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# Before task with name 'example_node' and path '('__pregel_pull', 'example_node')'
